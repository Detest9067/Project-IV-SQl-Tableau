# %%
import src
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/graham/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# src.create_season_table(1)
# src.create_season_table(2)
# src.create_season_table(3)
# src.create_season_table(4)

# %%
src.analyze_sentiment('season_1')
src.analyze_sentiment('season_2')
src.analyze_sentiment('season_3')
src.analyze_sentiment('season_4')

# %%
src.get_average_polarity('season_1')
# Out:
#                name  polarity_score
# 0           a voice        0.000000
# 1    addam marbrand        0.210750
# 2               all        0.000000
# 3    alliser thorne        0.170815
# 4        arya stark       -0.053775
# ..              ...             ...
# 141    waymar royce       -0.385850
# 142        wildling       -0.260086
# 143            will       -0.092957
# 144   wine merchant        0.053864
# 145           yoren       -0.094178
#
# [146 rows x 2 columns]

# %%
src.get_average_polarity('season_2')
# Out:
#                 name  polarity_score
# 0               ahsa        0.415800
# 1                all        0.076550
# 2          all three       -0.285600
# 3              alton        0.159274
# 4              amory        0.027778
# ..               ...             ...
# 142  wounded soldier       -0.058243
# 143             xaro        0.036876
# 144     yara greyjoy        0.033143
# 145          ygritte       -0.022636
# 146            yoren       -0.039619
#
# [147 rows x 2 columns]

# %%
src.get_average_polarity('season_3')
# Out:
#              name  polarity_score
# 0           anguy        0.020060
# 1      arya stark       -0.083530
# 2           balon        0.062929
# 3       barristan        0.028628
# 4           beric       -0.075695
# ..            ...             ...
# 119      wildling       -0.324300
# 120        willem        0.510600
# 121         woman        0.000000
# 122  yara greyjoy       -0.093240
# 123       ygritte       -0.052008
#
# [124 rows x 2 columns]

# %%
src.get_average_polarity('season_4')
# Out:
#               name  polarity_score
# 0            aemon        0.148725
# 1              all        0.000000
# 2     all together        0.285350
# 3          alliser       -0.025565
# 4    alliser thorn        0.046675
# ..             ...             ...
# 151          women        0.591300
# 152   yara greyjoy       -0.067394
# 153        yarwick       -0.148000
# 154        yarwyck        0.630900
# 155        ygritte        0.027279
#
# [156 rows x 2 columns]

# %%
src.top_characters('season_1')
# Out:
#                     name  avg_polarity  num_sentences
# 0              marillion      0.263108             13
# 1         alliser thorne      0.170815             13
# 2           benjen stark      0.153031             13
# 3                hot pie      0.141150              6
# 4                  varys      0.139446             65
# 5       lancel lannister      0.120567              6
# 6                mordane      0.110222              9
# 7                illyrio      0.107785             13
# 8  grand maester pycelle      0.107693             44
# 9            walder frey      0.102238             13

# %%
src.top_characters('season_2')
# Out:
#               name  avg_polarity  num_sentences
# 0            daisy      0.386050              6
# 1           doreah      0.315240             10
# 2            gilly      0.240789              9
# 3             saan      0.231971             14
# 4              ros      0.219189             18
# 5     roose bolton      0.169592             12
# 6            davos      0.165265             95
# 7        pyat pree      0.160273             15
# 8            alton      0.159274             31
# 9  margaery tyrell      0.159257             28

# %%
src.top_characters('season_3')
# Out:
#               name  avg_polarity  num_sentences
# 0   radzal mo eraz      0.451260             10
# 1    maester aemon      0.254114              7
# 2  margaery tyrell      0.222916             64
# 3    petyr baelish      0.179491             43
# 4           olyvar      0.173386              7
# 5         torturer      0.167067              9
# 6           walder      0.149987             24
# 7          hot pie      0.136980             10
# 8            loras      0.135063             19
# 9            guard      0.133763              8

# %%
src.top_characters('season_4')
# Out:
#                 name  avg_polarity  num_sentences
# 0            fennesz      0.521262              8
# 1             qyburn      0.369270             10
# 2            hizdahr      0.315490             10
# 3               mace      0.265511              9
# 4      maester aemon      0.218933              6
# 5             olyvar      0.216554             13
# 6        karl tanner      0.193129             17
# 7            myranda      0.172786              7
# 8  joffrey lannister      0.164497             37
# 9            hot pie      0.157367             15

# %%
src.bottom_characters('season_1')
# Out:
#                name  avg_polarity  num_sentences
# 0          wildling     -0.260086              7
# 1      king joffrey     -0.199563              8
# 2  gendry baratheon     -0.191944              9
# 3        khal drogo     -0.187623             13
# 4       syrio forel     -0.180170             30
# 5               pyp     -0.167007             14
# 6             grenn     -0.156279             24
# 7           rakharo     -0.155165             17
# 8             qotho     -0.150364             11
# 9    rodrick cassel     -0.148929              7

# %%
src.bottom_characters('season_2')
# Out:
#                name  avg_polarity  num_sentences
# 0             rorge     -0.427250              6
# 1          prisoner     -0.294667              9
# 2               men     -0.234614             14
# 3  rickard karstark     -0.231125             12
# 4              lord     -0.189033              6
# 5            quaith     -0.188457              7
# 6             roose     -0.178614              7
# 7        melisandre     -0.169771             45
# 8      lord mormont     -0.132817             18
# 9        gold cloak     -0.132622              9

# %%
src.bottom_characters('season_3')
# Out:
#                 name  avg_polarity  num_sentences
# 0  kraznys mo nakloz     -0.461825              8
# 1   rickard karstark     -0.292653             19
# 2        walder frey     -0.238410             10
# 3            kraznys     -0.224222             18
# 4       dolorous edd     -0.187975              8
# 5      theon greyjoy     -0.098726             50
# 6  stannis baratheon     -0.094579             62
# 7               mero     -0.094525             20
# 8         arya stark     -0.083530            104
# 9             daario     -0.082066             35

# %%
src.bottom_characters('season_4')
# Out:
#                name  avg_polarity  num_sentences
# 0              rast     -0.286825              8
# 1             mance     -0.187739             23
# 2              ralf     -0.176633              9
# 3               pyp     -0.155794             17
# 4             janos     -0.144167              9
# 5             guard     -0.142483              6
# 6            selyse     -0.138395             21
# 7             robin     -0.128455             20
# 8         lady anya     -0.123507             14
# 9  moles town whore     -0.120608             12
